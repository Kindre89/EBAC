# %% [markdown]
# # Módulo 07 - Tarefa 02
#
# #### 1) Carregue a base e garanta que a base está como deveria.
#
# Considere a base que você ajustou na lição passada. Carregue-a. Caso ainda haja alguma pendência, ajuste - lembre-se de que o scikitlearn não recebe variáveis em formato string, somente numéricas, e não aceita '*missings*'.
#
# - Separe 70% da base para treinamento e 30% para validação. Cada uma dessas partes terá dois objetos, um armazenando a variável resposta ```mau```e outro armazenando as variáveis explicativas (lembrando: sem variáveis string, já com as dummies).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.tree import plot_tree
from sklearn.tree import DecisionTreeClassifier
 
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score

from sklearn.model_selection import cross_val_score, train_test_split

# %%
# Importando a base de dados.
base_dados = pd.read_csv("demo02.csv")
base_dados
# Out:
#        sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos      idade  \
# 0         0                 1                1           0  58.832877
# 1         1                 0                1           0  52.356164
# 2         1                 0                1           0  52.356164
# 3         0                 1                1           0  46.224658
# 4         1                 1                0           0  29.230137
# ...     ...               ...              ...         ...        ...
# 16645     1                 0                1           0  54.109589
# 16646     1                 0                1           0  43.389041
# 16647     0                 1                1           0  30.005479
# 16648     0                 1                1           0  30.005479
# 16649     1                 0                1           0  33.936986
#
#        tempo_emprego  possui_celular  possui_fone_comercial  possui_fone  \
# ...

# %%
# Verificando os valores da minha coluna alvo.
base_dados["mau"].value_counts()
# Out:
# mau
# False    16260
# True       390
# Name: count, dtype: int64

# %%
base_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16650 entries, 0 to 16649
# Data columns (total 29 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   sexo                                    16650 non-null  int64
#  1   posse_de_veiculo                        16650 non-null  int64
#  2   posse_de_imovel                         16650 non-null  int64
#  3   qtd_filhos                              16650 non-null  int64
#  4   idade                                   16650 non-null  float64
#  5   tempo_emprego                           16650 non-null  float64
#  6   possui_celular                          16650 non-null  int64
#  7   possui_fone_comercial                   16650 non-null  int64
#  8   possui_fone                             16650 non-null  int64
#  9   possui_email                            16650 non-null  int64
# ...

# %%
# Separando a coluna "alvo" das colunas explicativas.
x = base_dados.drop("mau", axis=1)
y = base_dados["mau"]

# %% [markdown]
# #### 2) Vamos para o modelo:
#
# 1. Defina um objeto com a função da árvore de decisão vista em aula.
# 2. Treine o modelo com os dados que você separou para treinamento.
# 3. Visualize a árvore. Talvez você queira aumentar um pouco a figura.
# 4. Produza uma visualização da matriz de classificação (ou matriz de confusão) - coloque os rótulos como "aprovados" e "reprovados" - pois afinal de contas, são essas as decisões que se podem tomar com propostas de crédito.
# 5. Calcule a acurácia na base de treinamento

# %%
# Criação do modelo.
clf = DecisionTreeClassifier(random_state= 42)

# %%
# Treinando o modelo.
clf.fit(x, y)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Visualizando a árvore de decisão.
plt.figure(figsize=(32, 26))
plot_tree(clf, 
          filled=True, 
          class_names=["aprovados", "reprovados"], 
          feature_names=list(x.columns));
plt.show()

# %%
# Visualizando a matriz de confusão
preditos = clf.predict(x)
cm = confusion_matrix(y, preditos, labels=clf.classes_)
MatrizDeConfusao = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["aprovados", "reprovados"])

MatrizDeConfusao.plot();

# %%
# Verificando a acurácia
predict = clf.predict(x)
accuracy_score(y, predict)

# %% [markdown]
# #### 3) Vamos avaliar o modelo na base de testes
#
# 1. Classifique a base de teste de acordo com a árvore que você treinou no item 2.
# 2. Produza a visualização da matriz de confusão para a base de teste.
# 3. Calcule a acurácia da base de teste. Compare com a acurácia da base de treinamento.
# 4. Treine uma nova árvore com número mínimo de observações por folha de 5 e máximo de profundidade de 10. Use o random_state = 123. Avalie a matriz de classificação. Observe a distribuição da predição - qual a proporção de proponentes foram classificados como 'maus'?
# 5. Como ficaria a acurácia se você classificasse todos os contratos como 'bons'?

# %%
# Separando os dados de teste e validação.  
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.3, random_state=123)

# %%
# Visualização da matriz de confusão para a base de teste.
cm = confusion_matrix(y_test, clf.predict(x_test), labels=clf.classes_)
MatrizDeConfusao = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["bom", "mau"])

MatrizDeConfusao.plot()
plt.title("Matriz de Confusão ")
plt.show();

# %%
# Verificando a acurácia da base de teste.
predict = clf.predict(x_test)
accuracy_score(y_test, predict)

# %%
# Verificando a acurácia da base de treinamento.
predict = clf.predict(x_train)
accuracy_score(y_train, predict)

# %% [markdown]
# As duas bases de teste e treinamento apresentam uma acurácia de 99%

# %%
# Treinando uma nova árvore de decisão com as especificações fornecidas.

clf = DecisionTreeClassifier(min_samples_leaf=5, max_depth=10, random_state= 123)
clf.fit(x, y)

# %%
plt.figure(figsize=(25, 16))
plot_tree(clf, 
          filled=True, 
          class_names=["aprovados", "reprovados"], 
          feature_names=list(x.columns));
plt.show()

# %%
# Visualizando a matriz de Comfusão.
preditos = clf.predict(x)
cm = confusion_matrix(y, preditos, labels=clf.classes_)
MatrizDeConfusao = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["bom", "mau"])

MatrizDeConfusao.plot();

# %%
x.shape

# %%
((24+58)/16650)*100

# %% [markdown]
# O modelo classificou quase meio por cento dos dados como 'mau'.

# %%
# Classificando toda a acurácia como boa.

y_pred = np.array([False] * len(y_test))

# Calculando a acurácia.
accuracy_score(y_test, y_pred)

# %% [markdown]
# # Insight
# Os testes demonstram que faltam dados "maus" no modelo. Os testes tendem a prever que os dados são "bons", ao meu ver, pelo desbalanceamento de dados na nossa base (nossa base possui muitos dados apontando para "bom" e poucos para "mau"). Como no teste acima, que demonstra que se o modelo prever que todos os dados são "bons", a chance de ele acertar é quase de 98%.
